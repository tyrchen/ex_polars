# %% [markdown]
# ## Prepare environment
#
# IElixir has "boyle" to build an env and install dependencies for jupyter lab. See more in: https://hexdocs.pm/ielixir/Boyle.html. To install IElixir, please follow this guide: https://github.com/pprzetacznik/IElixir#install-kernel.

# %%
Boyle.mk("polars")
Boyle.activate("polars")
Boyle.install({:ex_polars, "~> 0.3.6-dev"})
# Out:
# All dependencies are up to date
# Resolving Hex dependencies...
# Dependency resolution completed:
# Unchanged:
#   deneb 0.2.2
#   elixir_uuid 1.2.1
#   ex_polars 0.3.6-dev
#   jason 1.2.2
#   rustler 0.22.0-rc.0
#   toml 0.5.2
#   typed_struct 0.2.1
# All dependencies are up to date
# ==> ex_polars
# Compiling NIF crate :expolars (native/expolars)...
#     Finished release [optimized] target(s) in 0.27s
# warning: redefining module CustomEnvironment (current version defined in memory)
#   mix.exs:1
# :ok

# %% [markdown]
# ## Import ExPolars DataFrame and Series
#
# The two major data structures in ExPolars are DataFrame and Series. They behave very similar to pandas. However due to the limitation of the elixir language,
# you have to import the overloaded operators for easy Series operations.

# %%
alias ExPolars.Series, as: S
alias ExPolars.DataFrame, as: DF
alias ExPolars.Datasets
import Kernel, except: [+: 2, -: 2, *: 2, /: 2, ==: 2, <>: 2, >: 2, >=: 2, <: 2, <=: 2]
import S, only: [+: 2, -: 2, *: 2, /: 2, ==: 2, <>: 2, >: 2, >=: 2, <: 2, <=: 2]
# Out:
# ExPolars.Series

# %% [markdown]
# ## Loading a DataFrame from file
#
# ExPolars supports to load dataframe from JSON, CSV and Parquet files. Below is an example of loading a csv file.
#
# Once file is loaded, you can inspect it by using `head`, `tail`, `get_columns`, etc. See all the functionalities in https://hexdocs.pm/ex_polars/ExPolars.DataFrame.html. Since I don't have enough time (a good excuse for being lazy), I just put the typespec without actual doc in the document.

# %%
{:ok, df} = DF.read_csv("./priv/datasets/airports.csv")
# Out:
# {:ok, shape: (3376, 7)
# ╭──────┬───────────────────────────┬──────────────────┬───────┬─────────┬──────────┬────────────╮
# │ iata ┆ name                      ┆ city             ┆ state ┆ country ┆ latitude ┆ longitude  │
# │ ---  ┆ ---                       ┆ ---              ┆ ---   ┆ ---     ┆ ---      ┆ ---        │
# │ str  ┆ str                       ┆ str              ┆ str   ┆ str     ┆ f64      ┆ f64        │
# ╞══════╪═══════════════════════════╪══════════════════╪═══════╪═════════╪══════════╪════════════╡
# │ 00M  ┆ Thigpen                   ┆ Bay Springs      ┆ MS    ┆ USA     ┆ 31.954   ┆ -8.9235e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 00R  ┆ Livingston Municipal      ┆ Livingston       ┆ TX    ┆ USA     ┆ 30.686   ┆ -9.5018e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 00V  ┆ Meadow Lake               ┆ Colorado Springs ┆ CO    ┆ USA     ┆ 38.946   ┆ -1.0457e2  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 01G  ┆ Perry-Warsaw              ┆ Perry            ┆ NY    ┆ USA     ┆ 42.741   ┆ -7.8052e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...  ┆ ...                       ┆ ...              ┆ ...   ┆ ...     ┆ ...      ┆ ...        │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZEF  ┆ Elkin Municipal           ┆ Elkin            ┆ NC    ┆ USA     ┆ 36.28    ┆ -8.0786e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZER  ┆ Schuylkill Cty/Joe Zerbey ┆ Pottsville       ┆ PA    ┆ USA     ┆ 40.706   ┆ -7.6373e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZPH  ┆ Zephyrhills Municipal     ┆ Zephyrhills      ┆ FL    ┆ USA     ┆ 28.228   ┆ -8.2156e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZUN  ┆ Black Rock                ┆ Zuni             ┆ NM    ┆ USA     ┆ 35.083   ┆ -1.08792e2 │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZZV  ┆ Zanesville Municipal      ┆ Zanesville       ┆ OH    ┆ USA     ┆ 39.944   ┆ -8.1892e1  │
# ╰──────┴───────────────────────────┴──────────────────┴───────┴─────────┴──────────┴────────────╯}

# %%
DF.tail(df)
# Out:
# {:ok, shape: (5, 7)
# ╭──────┬───────────────────────────┬─────────────┬───────┬─────────┬──────────┬────────────╮
# │ iata ┆ name                      ┆ city        ┆ state ┆ country ┆ latitude ┆ longitude  │
# │ ---  ┆ ---                       ┆ ---         ┆ ---   ┆ ---     ┆ ---      ┆ ---        │
# │ str  ┆ str                       ┆ str         ┆ str   ┆ str     ┆ f64      ┆ f64        │
# ╞══════╪═══════════════════════════╪═════════════╪═══════╪═════════╪══════════╪════════════╡
# │ ZEF  ┆ Elkin Municipal           ┆ Elkin       ┆ NC    ┆ USA     ┆ 36.28    ┆ -8.0786e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZER  ┆ Schuylkill Cty/Joe Zerbey ┆ Pottsville  ┆ PA    ┆ USA     ┆ 40.706   ┆ -7.6373e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZPH  ┆ Zephyrhills Municipal     ┆ Zephyrhills ┆ FL    ┆ USA     ┆ 28.228   ┆ -8.2156e1  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZUN  ┆ Black Rock                ┆ Zuni        ┆ NM    ┆ USA     ┆ 35.083   ┆ -1.08792e2 │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ZZV  ┆ Zanesville Municipal      ┆ Zanesville  ┆ OH    ┆ USA     ┆ 39.944   ┆ -8.1892e1  │
# ╰──────┴───────────────────────────┴─────────────┴───────┴─────────┴──────────┴────────────╯}

# %% [markdown]
# ## Interact with predefined datasets
#
# In `priv/datasets` there are many different datasets for you to use. These are good starting point if you'd like to explore the functionalities of ExPolars.

# %%
weather = ExPolars.Datasets.seattle_weather
# Out:
# shape: (1461, 6)
# ╭───────────────┬──────────┬──────────┬──────┬─────────┬──────────────╮
# │ precipitation ┆ temp_max ┆ temp_min ┆ wind ┆ weather ┆ date         │
# │ ---           ┆ ---      ┆ ---      ┆ ---  ┆ ---     ┆ ---          │
# │ f64           ┆ f64      ┆ f64      ┆ f64  ┆ str     ┆ date32(days) │
# ╞═══════════════╪══════════╪══════════╪══════╪═════════╪══════════════╡
# │ 0.0           ┆ 12.8     ┆ 5        ┆ 4.7  ┆ drizzle ┆ 2012-01-01   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 10.9          ┆ 10.6     ┆ 2.8      ┆ 4.5  ┆ rain    ┆ 2012-01-02   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.8           ┆ 11.7     ┆ 7.2      ┆ 2.3  ┆ rain    ┆ 2012-01-03   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 20.3          ┆ 12.2     ┆ 5.6      ┆ 4.7  ┆ rain    ┆ 2012-01-04   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...           ┆ ...      ┆ ...      ┆ ...  ┆ ...     ┆ ...          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 8.6           ┆ 4.4      ┆ 1.7      ┆ 2.9  ┆ fog     ┆ 2015-12-27   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.5           ┆ 5        ┆ 1.7      ┆ 1.3  ┆ fog     ┆ 2015-12-28   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0           ┆ 7.2      ┆ 0.6      ┆ 2.6  ┆ fog     ┆ 2015-12-29   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0           ┆ 5.6      ┆ -1e0     ┆ 3.4  ┆ sun     ┆ 2015-12-30   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0           ┆ 5.6      ┆ -2.1e0   ┆ 3.5  ┆ sun     ┆ 2015-12-31   │
# ╰───────────────┴──────────┴──────────┴──────┴─────────┴──────────────╯

# %% [markdown]
# ## Complicated Operations
#
# You can do complicated operations with ExPolars.
#
# Operations include:
#
# - window, e.g. rolling_min, rolling_max
# - aggregate, eg. min, max, mean, std, var
# - comparison, e.g. ==, <>, <, >, <=, >=
# - shift
# - filter
# - ...
#
# For example, below filter operation is equal to `df[df["temp_min"] < -5.0]` in pandas. Here you can see how Python's grammar (and magic functions) help to make the expressiveness much easier.

# %%
df = DF.filter(weather, DF.column(weather, "temp_min") < -5.0)
# Out:
# {:ok, shape: (4, 6)
# ╭───────────────┬──────────┬──────────┬──────┬─────────┬──────────────╮
# │ precipitation ┆ temp_max ┆ temp_min ┆ wind ┆ weather ┆ date         │
# │ ---           ┆ ---      ┆ ---      ┆ ---  ┆ ---     ┆ ---          │
# │ f64           ┆ f64      ┆ f64      ┆ f64  ┆ str     ┆ date32(days) │
# ╞═══════════════╪══════════╪══════════╪══════╪═════════╪══════════════╡
# │ 0.0           ┆ 0.0      ┆ -7.1e0   ┆ 3.1  ┆ sun     ┆ 2013-12-07   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0           ┆ 2.2      ┆ -6.6e0   ┆ 2.2  ┆ sun     ┆ 2013-12-08   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0           ┆ -5e-1    ┆ -5.5e0   ┆ 6.6  ┆ sun     ┆ 2014-02-05   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0           ┆ -1.6e0   ┆ -6e0     ┆ 4.5  ┆ sun     ┆ 2014-02-06   │
# ╰───────────────┴──────────┴──────────┴──────┴─────────┴──────────────╯}

# %% [markdown]
# ## DataFrame Persistence
#
# Right now ExPolars only support to persist the data frame to csv file. JSON/Parquet is not supported since the underlying library arrow hasn't support it: see: https://github.com/apache/arrow/blob/master/rust/parquet/README.md.

# %%
{:ok, csv} = DF.to_csv(df)
csv |> IO.puts
# Out:
# precipitation,temp_max,temp_min,wind,weather,date
# 0,0,-7.1,3.1,sun,2013-12-07
# 0,2.2,-6.6,2.2,sun,2013-12-08
# 0,-0.5,-5.5,6.6,sun,2014-02-05
# 0,-1.6,-6,4.5,sun,2014-02-06
# :ok

# %%
DF.to_csv_file(df, "/tmp/weather.csv")
# Out:
# {:ok, {}}

# %%
DF.read_csv("/tmp/weather.csv")
# Out:
# {:ok, shape: (4, 6)
# ╭───────────────┬──────────┬──────────┬──────┬─────────┬────────────╮
# │ precipitation ┆ temp_max ┆ temp_min ┆ wind ┆ weather ┆ date       │
# │ ---           ┆ ---      ┆ ---      ┆ ---  ┆ ---     ┆ ---        │
# │ i64           ┆ f64      ┆ f64      ┆ f64  ┆ str     ┆ str        │
# ╞═══════════════╪══════════╪══════════╪══════╪═════════╪════════════╡
# │ 0             ┆ 0.0      ┆ -7.1e0   ┆ 3.1  ┆ sun     ┆ 2013-12-07 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0             ┆ 2.2      ┆ -6.6e0   ┆ 2.2  ┆ sun     ┆ 2013-12-08 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0             ┆ -5e-1    ┆ -5.5e0   ┆ 6.6  ┆ sun     ┆ 2014-02-05 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0             ┆ -1.6e0   ┆ -6e0     ┆ 4.5  ┆ sun     ┆ 2014-02-06 │
# ╰───────────────┴──────────┴──────────┴──────┴─────────┴────────────╯}

# %% [markdown]
# ## Plotting
#
# Showing data as table won't give you much insights, so we need better visual encoding of the data. Normally it means using proper markers (point, line, bar, area, etc.) with proper x/y axis and colors to visualize the data. Pandas has built in support for matplotlib, and there's a big ecosystem around it (plotly, seaborn, altair, etc.). Personally I like the tools behind [altair](https://altair-viz.github.io/) a lot, which is [vega-lite](https://vega.github.io/vega-lite/). Thus I built a very simple library called [deneb](https://github.com/tyrchen/deneb), which is an elixir thin wrapper of vega-lite. ExPolars integrates with deneb and provide a simple, easy to use `plot_*` functionalities around dataframe:
#
# - `plot_by_type`: special purpose plots, e.g. candlestick plot
# - `plot_single`: plot a single chart with minimum inputs
# - `plot_repeat`: plot a grid of charts to compare with

# %%
DF.plot_single(weather, :tick, "date", "temp_max", color: "weather", width: 800, height: 400) |> Deneb.Viewer.display
# Out:
# <div id="deneb-chart-ceba0a65ca40413e9a2bdfe861a32e41"></div>
# <script type="text/javascript">
# (function(spec, embedOpt) {
#   const outputDiv = document.getElementById("deneb-chart-ceba0a65ca40413e9a2bdfe861a32e41");
#   const urls = {
#     "vega": "https://cdn.jsdelivr.net/npm/vega@5.18.0",
#     "vega-lite": "https://cdn.jsdelivr.net/npm/vega-lite@4.17.0",
#     "vega-embed": "https://cdn.jsdelivr.net/npm/vega-embed@6.15.0",
#   };
#   function loadScript(lib) {
#     return new Promise(function(resolve, reject) {
#       var s = document.createElement('script');
#       s.src = urls[lib];
#       s.async = true;
#       s.onload = () => resolve(urls[lib]);
#       s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     });
#   }
#   function showError(err) {
#     outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#     throw err;
#   }
#   function displayChart(vegaEmbed) {
#     vegaEmbed(outputDiv, spec, embedOpt)
#       .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#   }
#   if(typeof define === "function" && define.amd) {
#       // requirejs paths need '.js' extension stripped.
#       const paths = Object.keys(urls).reduce(function(paths, package) {
#           paths[package] = urls[package].replace(/\.js$/, "");
#           return paths
#       }, {})
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#   } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#   } else {
#       loadScript("vega")
#           .then(() => loadScript("vega-lite"))
#           .then(() => loadScript("vega-embed"))
#           .catch(showError)
#           .then(() => displayChart(vegaEmbed));
#   }
# })({"$schema":"https://vega.github.io/schema/vega-lite/v4.json","data":{"format":{"type":"csv"},"values":"precipitation,temp_max,temp_min,wind,weather,date\n0,12.8,5,4.7,drizzle,2012-01-01\n10.9,10.6,2.8,4.5,rain,2012-01-02\n0.8,11.7,7.2,2.3,rain,2012-01-03\n20.3,12.2,5.6,4.7,rain,2012-01-04\n1.3,8.9,2.8,6.1,rain,2012-01-05\n2.5,4.4,2.2,2.2,rain,2012-01-06\n0,7.2,2.8,2.3,rain,2012-01-07\n0,10,2.8,2,sun,2012-01-08\n4.3,9.4,5,3.4,rain,2012-01-09\n1,6.1,0.6,3.4,rain,2012-01-10\n0,6.1,-1.1,5.1,sun,2012-01-11\n0,6.1,-1.7,1.9,sun,2012-01-12\n0,5,-2.8,1.3,sun,2012-01-13\n4.1,4.4,0.6,5.3,snow,2012-01-14\n5.3,1.1,-3.3,3.2,snow,2012-01-15\n2.5,1.7,-2.8,5,snow,2012-01-16\n8.1,3.3,0,5.6,snow,2012-01-17\n19.8,0,-2.8,5,snow,2012-01-18\n15.2,-1.1,-2.8,1.6,snow,2012-01-19\n13.5,7.2,-1.1,2.3,snow,2012-01-20\n3,8.3,3.3,8.2,rain,2012-01-21\n6.1,6.7,2.2,4.8,rain,2012-01-22\n0,8.3,1.1,3.6,rain,2012-01-23\n8.6,10,2.2,5.1,rain,2012-01-24\n8.1,8.9,4.4,5.4,rain,2012-01-25\n4.8,8.9,1.1,4.8,rain,2012-01-26\n0,6.7,-2.2,1.4,drizzle,2012-01-27\n0,6.7,0.6,2.2,rain,2012-01-28\n27.7,9.4,3.9,4.5,rain,2012-01-29\n3.6,8.3,6.1,5.1,rain,2012-01-30\n1.8,9.4,6.1,3.9,rain,2012-01-31\n13.5,8.9,3.3,2.7,rain,2012-02-01\n0,8.3,1.7,2.6,sun,2012-02-02\n0,14.4,2.2,5.3,sun,2012-02-03\n0,15.6,5,4.3,sun,2012-02-04\n0,13.9,1.7,2.9,sun,2012-02-05\n0,16.1,1.7,5,sun,2012-02-06\n0.3,15.6,7.8,5.3,rain,2012-02-07\n2.8,10,5,2.7,rain,2012-02-08\n2.5,11.1,7.8,2.4,rain,2012-02-09\n2.5,12.8,6.7,3,rain,2012-02-10\n0.8,8.9,5.6,3.4,rain,2012-02-11\n1,8.3,5,1.3,rain,2012-02-12\n11.4,7.2,4.4,1.4,rain,2012-02-13\n2.5,6.7,1.1,3.1,rain,2012-02-14\n0,7.2,0.6,1.8,drizzle,2012-02-15\n1.8,7.2,3.3,2.1,rain,2012-02-16\n17.3,10,4.4,3.4,rain,2012-02-17\n6.4,6.7,3.9,8.1,rain,2012-02-18\n0,6.7,2.2,4.7,sun,2012-02-19\n3,7.8,1.7,2.9,rain,2012-02-20\n0.8,10,7.8,7.5,rain,2012-02-21\n8.6,10,2.8,5.9,rain,2012-02-22\n0,8.3,2.8,3.9,sun,2012-02-23\n11.4,6.7,4.4,3.5,rain,2012-02-24\n0,7.2,2.8,6.4,rain,2012-02-25\n1.3,5,-1.1,3.4,snow,2012-02-26\n0,6.7,-2.2,3,sun,2012-02-27\n3.6,6.7,-0.6,4.2,snow,2012-02-28\n0.8,5,1.1,7,snow,2012-02-29\n0,6.1,1.1,3.1,sun,2012-03-01\n2,6.7,3.9,5.1,rain,2012-03-02\n0,12.2,6.7,7,sun,2012-03-03\n0,10.6,6.7,5.6,rain,2012-03-04\n6.9,7.8,1.1,6.2,rain,2012-03-05\n0.5,6.7,0,2.7,snow,2012-03-06\n0,8.9,-1.7,2.7,sun,2012-03-07\n0,15.6,0.6,2.5,sun,2012-03-08\n3.6,9.4,5,2.8,rain,2012-03-09\n10.4,7.2,6.1,3.4,rain,2012-03-10\n13.7,6.7,2.8,5.8,rain,2012-03-11\n19.3,8.3,0.6,6.2,snow,2012-03-12\n9.4,5.6,0.6,5.3,snow,2012-03-13\n8.6,7.8,1.1,4.7,rain,2012-03-14\n23.9,11.1,5.6,5.8,snow,2012-03-15\n8.4,8.9,3.9,5.1,rain,2012-03-16\n9.4,10,0.6,3.8,snow,2012-03-17\n3.6,5,-0.6,2.7,rain,2012-03-18\n2,7.2,-1.1,3,rain,2012-03-19\n3.6,7.8,2.2,6.4,rain,2012-03-20\n1.3,8.9,1.1,2.5,rain,2012-03-21\n4.1,10,1.7,2.1,rain,2012-03-22\n0,12.2,0.6,2.8,sun,2012-03-23\n0,15,3.3,5.2,sun,2012-03-24\n0,13.3,2.2,2.7,rain,2012-03-25\n0,12.8,6.1,4.3,drizzle,2012-03-26\n4.8,14.4,6.7,3.8,rain,2012-03-27\n1.3,10.6,7.2,5.9,rain,2012-03-28\n27.4,10,6.1,4.4,rain,2012-03-29\n5.6,9.4,5,4.7,rain,2012-03-30\n13.2,10,2.8,3.4,rain,2012-03-31\n1.5,8.9,4.4,6.8,rain,2012-04-01\n0,16.7,4.4,3.1,sun,2012-04-02\n1.5,11.7,3.3,3.1,rain,2012-04-03\n0,10.6,2.8,2.1,sun,2012-04-04\n4.6,9.4,2.8,1.8,snow,2012-04-05\n0.3,11.1,3.3,2.6,rain,2012-04-06\n0,16.1,1.7,4.3,sun,2012-04-07\n0,21.1,7.2,4.1,sun,2012-04-08\n0,20,6.1,2.1,sun,2012-04-09\n0,17.8,8.9,3.2,rain,2012-04-10\n2.3,11.1,7.2,2.6,rain,2012-04-11\n0.5,13.9,5.6,2.6,rain,2012-04-12\n0,15,3.9,4,drizzle,2012-04-13\n0,15.6,3.3,3,sun,2012-04-14\n0,16.1,7.2,2.9,rain,2012-04-15\n8.1,13.3,6.7,5.8,rain,2012-04-16\n1.8,10,4.4,2,rain,2012-04-17\n1.8,13.3,7.2,3.9,rain,2012-04-18\n10.9,13.9,5,2.6,rain,2012-04-19\n6.6,13.3,6.7,2.7,rain,2012-04-20\n0,20,4.4,2.3,sun,2012-04-21\n0,23.3,8.3,2.6,rain,2012-04-22\n0,21.7,8.9,3.5,sun,2012-04-23\n4.3,13.9,10,2.8,rain,2012-04-24\n10.7,16.7,8.9,2.6,rain,2012-04-25\n3.8,13.9,6.7,5.2,rain,2012-04-26\n0.8,13.3,6.1,4.8,rain,2012-04-27\n0,16.1,8.3,2.5,drizzle,2012-04-28\n4.3,15.6,8.9 ...

# %%
DF.plot_repeat(weather, :circle, "date", ["temp_max", "temp_min", "wind"], color: "weather", width: 800, height: 500, columns: 1) |> Deneb.Viewer.display
# Out:
# <div id="deneb-chart-bc1a6714c75f4b198a80393c56efc324"></div>
# <script type="text/javascript">
# (function(spec, embedOpt) {
#   const outputDiv = document.getElementById("deneb-chart-bc1a6714c75f4b198a80393c56efc324");
#   const urls = {
#     "vega": "https://cdn.jsdelivr.net/npm/vega@5.18.0",
#     "vega-lite": "https://cdn.jsdelivr.net/npm/vega-lite@4.17.0",
#     "vega-embed": "https://cdn.jsdelivr.net/npm/vega-embed@6.15.0",
#   };
#   function loadScript(lib) {
#     return new Promise(function(resolve, reject) {
#       var s = document.createElement('script');
#       s.src = urls[lib];
#       s.async = true;
#       s.onload = () => resolve(urls[lib]);
#       s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#       document.getElementsByTagName("head")[0].appendChild(s);
#     });
#   }
#   function showError(err) {
#     outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#     throw err;
#   }
#   function displayChart(vegaEmbed) {
#     vegaEmbed(outputDiv, spec, embedOpt)
#       .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#   }
#   if(typeof define === "function" && define.amd) {
#       // requirejs paths need '.js' extension stripped.
#       const paths = Object.keys(urls).reduce(function(paths, package) {
#           paths[package] = urls[package].replace(/\.js$/, "");
#           return paths
#       }, {})
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#   } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#   } else {
#       loadScript("vega")
#           .then(() => loadScript("vega-lite"))
#           .then(() => loadScript("vega-embed"))
#           .catch(showError)
#           .then(() => displayChart(vegaEmbed));
#   }
# })({"$schema":"https://vega.github.io/schema/vega-lite/v4.json","data":{"format":{"type":"csv"},"values":"precipitation,temp_max,temp_min,wind,weather,date\n0,12.8,5,4.7,drizzle,2012-01-01\n10.9,10.6,2.8,4.5,rain,2012-01-02\n0.8,11.7,7.2,2.3,rain,2012-01-03\n20.3,12.2,5.6,4.7,rain,2012-01-04\n1.3,8.9,2.8,6.1,rain,2012-01-05\n2.5,4.4,2.2,2.2,rain,2012-01-06\n0,7.2,2.8,2.3,rain,2012-01-07\n0,10,2.8,2,sun,2012-01-08\n4.3,9.4,5,3.4,rain,2012-01-09\n1,6.1,0.6,3.4,rain,2012-01-10\n0,6.1,-1.1,5.1,sun,2012-01-11\n0,6.1,-1.7,1.9,sun,2012-01-12\n0,5,-2.8,1.3,sun,2012-01-13\n4.1,4.4,0.6,5.3,snow,2012-01-14\n5.3,1.1,-3.3,3.2,snow,2012-01-15\n2.5,1.7,-2.8,5,snow,2012-01-16\n8.1,3.3,0,5.6,snow,2012-01-17\n19.8,0,-2.8,5,snow,2012-01-18\n15.2,-1.1,-2.8,1.6,snow,2012-01-19\n13.5,7.2,-1.1,2.3,snow,2012-01-20\n3,8.3,3.3,8.2,rain,2012-01-21\n6.1,6.7,2.2,4.8,rain,2012-01-22\n0,8.3,1.1,3.6,rain,2012-01-23\n8.6,10,2.2,5.1,rain,2012-01-24\n8.1,8.9,4.4,5.4,rain,2012-01-25\n4.8,8.9,1.1,4.8,rain,2012-01-26\n0,6.7,-2.2,1.4,drizzle,2012-01-27\n0,6.7,0.6,2.2,rain,2012-01-28\n27.7,9.4,3.9,4.5,rain,2012-01-29\n3.6,8.3,6.1,5.1,rain,2012-01-30\n1.8,9.4,6.1,3.9,rain,2012-01-31\n13.5,8.9,3.3,2.7,rain,2012-02-01\n0,8.3,1.7,2.6,sun,2012-02-02\n0,14.4,2.2,5.3,sun,2012-02-03\n0,15.6,5,4.3,sun,2012-02-04\n0,13.9,1.7,2.9,sun,2012-02-05\n0,16.1,1.7,5,sun,2012-02-06\n0.3,15.6,7.8,5.3,rain,2012-02-07\n2.8,10,5,2.7,rain,2012-02-08\n2.5,11.1,7.8,2.4,rain,2012-02-09\n2.5,12.8,6.7,3,rain,2012-02-10\n0.8,8.9,5.6,3.4,rain,2012-02-11\n1,8.3,5,1.3,rain,2012-02-12\n11.4,7.2,4.4,1.4,rain,2012-02-13\n2.5,6.7,1.1,3.1,rain,2012-02-14\n0,7.2,0.6,1.8,drizzle,2012-02-15\n1.8,7.2,3.3,2.1,rain,2012-02-16\n17.3,10,4.4,3.4,rain,2012-02-17\n6.4,6.7,3.9,8.1,rain,2012-02-18\n0,6.7,2.2,4.7,sun,2012-02-19\n3,7.8,1.7,2.9,rain,2012-02-20\n0.8,10,7.8,7.5,rain,2012-02-21\n8.6,10,2.8,5.9,rain,2012-02-22\n0,8.3,2.8,3.9,sun,2012-02-23\n11.4,6.7,4.4,3.5,rain,2012-02-24\n0,7.2,2.8,6.4,rain,2012-02-25\n1.3,5,-1.1,3.4,snow,2012-02-26\n0,6.7,-2.2,3,sun,2012-02-27\n3.6,6.7,-0.6,4.2,snow,2012-02-28\n0.8,5,1.1,7,snow,2012-02-29\n0,6.1,1.1,3.1,sun,2012-03-01\n2,6.7,3.9,5.1,rain,2012-03-02\n0,12.2,6.7,7,sun,2012-03-03\n0,10.6,6.7,5.6,rain,2012-03-04\n6.9,7.8,1.1,6.2,rain,2012-03-05\n0.5,6.7,0,2.7,snow,2012-03-06\n0,8.9,-1.7,2.7,sun,2012-03-07\n0,15.6,0.6,2.5,sun,2012-03-08\n3.6,9.4,5,2.8,rain,2012-03-09\n10.4,7.2,6.1,3.4,rain,2012-03-10\n13.7,6.7,2.8,5.8,rain,2012-03-11\n19.3,8.3,0.6,6.2,snow,2012-03-12\n9.4,5.6,0.6,5.3,snow,2012-03-13\n8.6,7.8,1.1,4.7,rain,2012-03-14\n23.9,11.1,5.6,5.8,snow,2012-03-15\n8.4,8.9,3.9,5.1,rain,2012-03-16\n9.4,10,0.6,3.8,snow,2012-03-17\n3.6,5,-0.6,2.7,rain,2012-03-18\n2,7.2,-1.1,3,rain,2012-03-19\n3.6,7.8,2.2,6.4,rain,2012-03-20\n1.3,8.9,1.1,2.5,rain,2012-03-21\n4.1,10,1.7,2.1,rain,2012-03-22\n0,12.2,0.6,2.8,sun,2012-03-23\n0,15,3.3,5.2,sun,2012-03-24\n0,13.3,2.2,2.7,rain,2012-03-25\n0,12.8,6.1,4.3,drizzle,2012-03-26\n4.8,14.4,6.7,3.8,rain,2012-03-27\n1.3,10.6,7.2,5.9,rain,2012-03-28\n27.4,10,6.1,4.4,rain,2012-03-29\n5.6,9.4,5,4.7,rain,2012-03-30\n13.2,10,2.8,3.4,rain,2012-03-31\n1.5,8.9,4.4,6.8,rain,2012-04-01\n0,16.7,4.4,3.1,sun,2012-04-02\n1.5,11.7,3.3,3.1,rain,2012-04-03\n0,10.6,2.8,2.1,sun,2012-04-04\n4.6,9.4,2.8,1.8,snow,2012-04-05\n0.3,11.1,3.3,2.6,rain,2012-04-06\n0,16.1,1.7,4.3,sun,2012-04-07\n0,21.1,7.2,4.1,sun,2012-04-08\n0,20,6.1,2.1,sun,2012-04-09\n0,17.8,8.9,3.2,rain,2012-04-10\n2.3,11.1,7.2,2.6,rain,2012-04-11\n0.5,13.9,5.6,2.6,rain,2012-04-12\n0,15,3.9,4,drizzle,2012-04-13\n0,15.6,3.3,3,sun,2012-04-14\n0,16.1,7.2,2.9,rain,2012-04-15\n8.1,13.3,6.7,5.8,rain,2012-04-16\n1.8,10,4.4,2,rain,2012-04-17\n1.8,13.3,7.2,3.9,rain,2012-04-18\n10.9,13.9,5,2.6,rain,2012-04-19\n6.6,13.3,6.7,2.7,rain,2012-04-20\n0,20,4.4,2.3,sun,2012-04-21\n0,23.3,8.3,2.6,rain,2012-04-22\n0,21.7,8.9,3.5,sun,2012-04-23\n4.3,13.9,10,2.8,rain,2012-04-24\n10.7,16.7,8.9,2.6,rain,2012-04-25\n3.8,13.9,6.7,5.2,rain,2012-04-26\n0.8,13.3,6.1,4.8,rain,2012-04-27\n0,16.1,8.3,2.5,drizzle,2012-04-28\n4.3,15.6,8.9 ...
